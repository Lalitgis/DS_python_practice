# %% [markdown]
# Q1: we have subject math science nepali, and students with corresponding marks on individual subject. considering 40 as pass mark, find whether student has passed or failed??

# %%
data1={
    "students": ["math", "science", "nepali"],
    "Ram": [40,60,80],
    "Sita": [60,35,40]
}

# %%
data1
# Out:
# {'students': ['math', 'science', 'nepali'],
#  'Ram': [40, 60, 80],
#  'Sita': [60, 35, 40]}

# %%
# importing librabries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# creating df
data = {
    "name":['Ram','Shyam','Hari','Sita','Gita'],
    "id":[1,2,3,4,5]}

# %%
df = pd.DataFrame(data)
df
# Out:
#     name  id
# 0    Ram   1
# 1  Shyam   2
# 2   Hari   3
# 3   Sita   4
# 4   Gita   5

# %%
# # methods to assign the variables

# df["subject_marks"]=100
# df["pass_marks"]=40
# df["Total_marks"]=500
# df["maths"]=[55,65,75,32,45]

# %%
df
# Out:
#     name  id
# 0    Ram   1
# 1  Shyam   2
# 2   Hari   3
# 3   Sita   4
# 4   Gita   5

# %%
# new methods to assign the value using pandas

df =df.assign(
            Subject_Marks =100,
            Pass_marks =40,
            Total_marks =500,
            Maths =[55,65,70,32,45],
            Science = [80,75,65,30,38],
            Social = [66,56,76,30,54],
            English=[68,76,43,75,44],
            computer = [70,67,87,90,54])

# %%
df.head()
# Out:
#     name  id  Subject_Marks  Pass_marks  Total_marks  Maths  Science  Social  \
# 0    Ram   1            100          40          500     55       80      66
# 1  Shyam   2            100          40          500     65       75      56
# 2   Hari   3            100          40          500     70       65      76
# 3   Sita   4            100          40          500     32       30      30
# 4   Gita   5            100          40          500     45       38      54
#
#    English  computer
# 0       68        70
# 1       76        67
# 2       43        87
# 3       75        90
# 4       44        54

# %%
# new_logic = df["Maths"]>=df["Pass_marks"]
# new_logic

# %%
# or logic
# new_logic = (df["Maths"]>=df["Pass_marks"])| (df["Science"]>=df["Pass_marks"])
# df[new_logic]

# %%
# # and logic
# new_logic = (df["Maths"]>=df["Pass_marks"])& (df["Science"]>=df["Pass_marks"])
# df[new_logic]

# %%
# ultimate code
passed = (
      (df["Maths"]>= df["Pass_marks"])
    & (df["English"] >= df["Pass_marks"])
    & (df["computer"] >= df["Pass_marks"])
    & (df["Science"] >= df["Pass_marks"])
    & (df["Social"] >= df["Pass_marks"])
)

# %%
df.loc[passed, 'remarks'] = 'Pass'

# %%
df.fillna('fail')
# Out:
#     name  id  Subject_Marks  Pass_marks  Total_marks  Maths  Science  Social  \
# 0    Ram   1            100          40          500     55       80      66
# 1  Shyam   2            100          40          500     65       75      56
# 2   Hari   3            100          40          500     70       65      76
# 3   Sita   4            100          40          500     32       30      30
# 4   Gita   5            100          40          500     45       38      54
#
#    English  computer remarks
# 0       68        70    Pass
# 1       76        67    Pass
# 2       43        87    Pass
# 3       75        90    fail
# 4       44        54    fail

# %%
df.loc[~passed]
# Out:
#    name  id  Subject_Marks  Pass_marks  Total_marks  Maths  Science  Social  \
# 3  Sita   4            100          40          500     32       30      30
# 4  Gita   5            100          40          500     45       38      54
#
#    English  computer remarks
# 3       75        90     NaN
# 4       44        54     NaN

# %%
df.fillna("failed")
# Out:
#     name  id  Subject_Marks  Pass_marks  Total_marks  Maths  Science  Social  \
# 0    Ram   1            100          40          500     55       80      66
# 1  Shyam   2            100          40          500     65       75      56
# 2   Hari   3            100          40          500     70       65      76
# 3   Sita   4            100          40          500     32       30      30
# 4   Gita   5            100          40          500     45       38      54
#
#    English  computer remarks
# 0       68        70    Pass
# 1       76        67    Pass
# 2       43        87    Pass
# 3       75        90  failed
# 4       44        54  failed

# %%
# Grace Marks problems
grace_threshold =35
science_grace = (df['Science']<df['Pass_marks']) & (df['Science']>=35)
df.loc[science_grace, 'Science']=df.Pass_marks

# %%
df.fillna('failed', inplace=True)

# %%
df
# Out:
#     name  id  Subject_Marks  Pass_marks  Total_marks  Maths  Science  Social  \
# 0    Ram   1            100          40          500     55       80      66
# 1  Shyam   2            100          40          500     65       75      56
# 2   Hari   3            100          40          500     70       65      76
# 3   Sita   4            100          40          500     32       30      30
# 4   Gita   5            100          40          500     45       40      54
#
#    English  computer remarks
# 0       68        70    Pass
# 1       76        67    Pass
# 2       43        87    Pass
# 3       75        90  failed
# 4       44        54  failed

# %%
subjects =[
    'Maths', 
    'Science',
    'Social',
    'English',
    'computer'
]

for sub in subjects:
    science_grace =(df['Science']<df['Pass_marks']) & (df['Science']>=35)
    df.loc[science_grace, sub]=df.Pass_marks

# %%
df
# Out:
#     name  id  Subject_Marks  Pass_marks  Total_marks  Maths  Science  Social  \
# 0    Ram   1            100          40          500     55       80      66
# 1  Shyam   2            100          40          500     65       75      56
# 2   Hari   3            100          40          500     70       65      76
# 3   Sita   4            100          40          500     32       30      30
# 4   Gita   5            100          40          500     45       40      54
#
#    English  computer remarks
# 0       68        70    Pass
# 1       76        67    Pass
# 2       43        87    Pass
# 3       75        90  failed
# 4       44        54  failed

# %%
my_str = str()
for sub in subjects:
    failed = (df[sub]<df["Pass_marks"])
    passed = (df[sub]>= df["Pass_marks"])
    
    if failed.any():
        my_str =my_str+sub
        df.loc[failed, 'remarks']=my_str

# %%
df
# Out:
#     name  id  Subject_Marks  Pass_marks  Total_marks  Maths  Science  Social  \
# 0    Ram   1            100          40          500     55       80      66
# 1  Shyam   2            100          40          500     65       75      56
# 2   Hari   3            100          40          500     70       65      76
# 3   Sita   4            100          40          500     32       30      30
# 4   Gita   5            100          40          500     45       40      54
#
#    English  computer             remarks
# 0       68        70                Pass
# 1       76        67                Pass
# 2       43        87                Pass
# 3       75        90  MathsScienceSocial
# 4       44        54              failed

# %%
df['Obtained_marks']=df.iloc[:,5:10].sum(axis=1)
df['Percentage'] = ((df['Obtained_marks']/df['Total_marks'])*100)
df['remark']=""
df['grace'] = ""
df
# Out:
#     name  id  Subject_Marks  Pass_marks  Total_marks  Maths  Science  Social  \
# 0    Ram   1            100          40          500     55       80      66
# 1  Shyam   2            100          40          500     65       75      56
# 2   Hari   3            100          40          500     70       65      76
# 3   Sita   4            100          40          500     32       30      30
# 4   Gita   5            100          40          500     45       40      54
#
#    English  computer             remarks  Obtained_marks  Percentage remark  \
# 0       68        70                Pass             339        67.8
# 1       76        67                Pass             339        67.8
# 2       43        87                Pass             341        68.2
# 3       75        90  MathsScienceSocial             257        51.4
# 4       44        54              failed             237        47.4
#
#   grace
# 0
# 1
# 2
# 3
# 4

# %%
df.loc[df['Maths'] < 35,'remark']='Maths'
df.loc[df['Science'] < 35,'remark']=df[df['Science'] < 35]['remark']+' Science'
df.loc[df['Social'] < 35,'remark']=df[df['Social'] < 35]['remark']+' Social'
df.loc[df['English'] < 35,'remark']=df[df['English'] < 35]['remark']+' English'
df.loc[df['computer'] < 35,'remark']=df[df['computer'] < 35]['remark']+' computer'

# %%
df
# Out:
#     name  id  Subject_Marks  Pass_marks  Total_marks  Maths  Science  Social  \
# 0    Ram   1            100          40          500     55       80      66
# 1  Shyam   2            100          40          500     65       75      56
# 2   Hari   3            100          40          500     70       65      76
# 3   Sita   4            100          40          500     32       30      30
# 4   Gita   5            100          40          500     45       40      54
#
#    English  computer             remarks  Obtained_marks  Percentage  \
# 0       68        70                Pass             339        67.8
# 1       76        67                Pass             339        67.8
# 2       43        87                Pass             341        68.2
# 3       75        90  MathsScienceSocial             257        51.4
# 4       44        54              failed             237        47.4
#
#                  remark grace
# 0
# 1
# 2
# 3  Maths Science Social
# 4
